# %% [markdown]
# # Indonesian Coastlines Combined
#
#
# * Load stack of all available Landsat 5, 7, 8 and 9 satellite imagery for a location
# * Convert each satellite image into a remote sensing water index (MNDWI)
# * For each satellite image, model ocean tides into a grid based on exact time of image acquisition
# * Interpolate tide heights into spatial extent of image stack using the [FES2014 global tide model](https://github.com/GeoscienceAustralia/dea-coastlines/wiki/Setting-up-tidal-models-for-DEA-Coastlines)
# * Mask out high and low tide pixels by removing all observations acquired outside of 50 percent of the observed tidal range centered over mean sea level
# * Combine tidally-masked data into annual median composites representing the most representative position of the coastline at approximately mean sea level each year
# * Apply morphological extraction algorithms to mask annual median composite rasters to a valid coastal region
# * Extract waterline vectors using subpixel waterline extraction ([Bishop-Taylor et al. 2019b](https://doi.org/10.3390/rs11242984))
# * Compute rates of coastal change at every 30 m using linear regression
#
# This is an interactive version of the code intended for prototyping; to run this analysis at scale, use the [command line tools](DEACoastlines_generation_CLI.ipynb).
#
# ---

# %% [markdown]
# ## Getting started
#
# Set working directory to top level of repository to ensure links work correctly:

# %%
cd ..
# Out:
# /home/jovyan/dev/coastlines

# %% [markdown]
# ### Load packages
#
# First we import the required Python packages, then we connect to the database, and load the catalog of virtual products.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from odc.stac import configure_s3_access
from dea_tools.spatial import subpixel_contours
from datacube.utils.dask import start_local_dask
import geopandas as gpd
from pathlib import Path

from coastlines.vector import (
    contours_preprocess,
    contour_certainty,
    points_certainty,
    generate_hotspots,
)

from coastlines.combined import (
    load_and_mask_data,
    export_results,
    filter_by_tides,
    generate_yearly_composites,
    mask_pixels_by_tide,
    sanitise_tile_id,
    mask_pixels_by_hillshadow,
)

from ipyleaflet import basemaps

from coastlines.utils import CoastlinesException, load_config, get_study_site_geometry
import os

os.environ["USE_PYGEOS"] = "0"

# %%
os.environ["AWS_DEFAULT_REGION"] = "us-west-2"

if "AWS_NO_SIGN_REQUEST" in os.environ:
    del os.environ["AWS_NO_SIGN_REQUEST"]

# %%
# Create local dask client for parallelisation
dask_client = start_local_dask(
    n_workers=2, threads_per_worker=16, mem_safety_margin="2GB"
)

# Configure S3 access including request payer
_ = configure_s3_access(
    requester_pays=True,
    cloud_defaults=True,
)

dask_client
# Out:
# <Client: 'tcp://127.0.0.1:33739' processes=2 threads=32, memory=30.14 GiB>

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Set analysis parameters

# %%
# Config
version = "testing"
config_path = "configs/indonesia_coastlines_config_datacube_development.yaml"
config = load_config(config_path)

# Tide data and config
tide_data_location = f"/home/jovyan/data/coastlines/tide_models"

DEBUG = True

# %%
# # Check tide models
# from eo_tides.utils import list_models

# models = list_models(directory=tide_data_location, show_supported=False)
# print(models)

# %%
study_area = "1869,49"

geometry = get_study_site_geometry(config.input.grid_path, study_area)

geometry = geometry.to_crs(config.output.crs).buffer(config.options.load_buffer_distance).to_crs("epsg:4326")
bbox = geometry.boundingbox.bbox

# View the AoI
geometry.explore(tiles=basemaps.Esri.WorldImagery)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_452d0f272a347e724a6f7777cb7d148b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_452d0f272a347e724a6f7777cb7d148b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_452d0f272a347e724a6f7777cb7d148b = L.map(
#                 &quot;map_452d0f272a347e724a6f7777cb7d148b&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44d358eaad519e5fff9d8bec8f1ca2ca = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_44d358eaad519e5fff9d8bec8f1ca2ca.addTo(map_452d0f272a347e724a6f7777cb7d148b);
#
#
#
#         function geo_json_7028dce4049cc6f3c26a3425fc37d316_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_7028dce4049cc6f3c26a3425fc37d316 = L.geoJson(null, {
#                 onEachFeature: geo_json_7028dce4049cc6f3c26a3425fc37d316_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_7028dce4049cc6f3c26a3425fc37d316_add (data) {
#             geo_json_7028dce4049cc6f3c26a3425fc37d316
#                 .addData(data);
#         }
#             geo_json_7028dce4049cc6f3c26a3425fc37d316_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[111.75042134446846, -6.790394577870169], [111.8402528728804, -6.790394577870169], [111.84126873897115, -6.790432582549898], [111.8422748217161, -6.790546230600687], [111.84326143198848, -6.79073442758132], [111.844219068192, -6.7909953611358524], [111.84513850776653, -6.7913265184443805], [111.8460108960063, -6.791724710418531], [111.84682783133579, -6.792186102408852], [111.84758144622106, -6.792706251128554], [111.84826448293886, -6.793280147438252], [111.84887036347222, -6.793902264579924], [111.84939325286038, -6.794566611395798], [111.84982811539268, -6.795266790019934], [111.85017076310524, -6.795996057487132], [111.85041789611326, -6.796747390666088], [111.85056713439079, -6.797513553891632], [111.85061704069162, -6.7982871686449], [111.85061704069162, -6.889355827653395], [111.85056713439079, -6.890129587322191], [111.85041789611326, -6.8908958964740545], [111.85017076310524, -6.89164737508065], [111.84982811539268, -6.892376785907181], [111.84939325286038, -6.8930771042141625], [111.84887036347222, -6.8937415854139115], [111.84826448293886, -6.894363830029962], [111.84758144622106, -6.894937845333663], [111.84682783133579, -6.895458103064047], [111.8460108960063, -6.8959195926749475], [111.84513850776653, -6.896317869596196], [111.844219068192, -6.896649098043917], [111.84326143198848, -6.896910087967367], [111.8422748217161, -6.897098325776228], [111.84126873897115, -6.897211998552276], [111.8402528728804, -6.8972500115120585], [111.75042134446846, -6.8972500115120585], [111.74940547837772, -6.897211998552276], [111.74839939563273, -6.897098325776228], [111.74741278536038, -6.896910087967367], [111.74645514915686, -6.896649098043917], [111.74553570958233, -6.896317869596196], [111.74466332134253, -6.8959195926749475], [111.74384638601306, -6.895458103064047], [111.74309277112778, -6.894937845333663], [111.74240973440999, -6.894363830029962], [111.74180385387663, -6.8937415854139115], [111.74128096448847, -6.8930771042141625], [111.74084610195617, -6.892376785907181], [111.74050345424361, -6.89164737508065], [111.74025632123559, -6.8908958964740545], [111.74010708295808, -6.890129587322191], [111.74005717665725, -6.889355827653395], [111.74005717665725, -6.7982871686449], [111.74010708295808, -6.797513553891632], [111.74025632123559, -6.796747390666088], [111.74050345424361, -6.795996057487132], [111.74084610195617, -6.795266790019934], [111.74128096448847, -6.794566611395798], [111.74180385387663, -6.793902264579924], [111.74240973440999, -6.793280147438252], [111.74309277112778, -6.792706251128554], [111.74384638601306, -6.792186102408852], [111.74466332134253, -6.791724710418531], [111.74553570958233, -6.7913265184443805], [111.74645514915686, -6.7909953611358524], [111.74741278536038, -6.79073442758132], [111.74839939563273, -6.790546230600687], [111.74940547837772, -6.790432582549898], [111.75042134446846, -6.790394577870169]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;});
#         geo_json_7028dce4049cc6f3c26a3425fc37d316.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_7028dce4049cc6f3c26a3425fc37d316.ad

# %%
# Output config
output_dir = Path(
    f"{config.output.location.rstrip('/')}/{version}/{sanitise_tile_id(study_area)}_{version}"
)
output_dir.mkdir(exist_ok=True, parents=True)
output_cache_zarr = (
    output_dir / f"{sanitise_tile_id(study_area)}_{version}_combined_ds.zarr"
)

# %% [markdown]
# ## Loading data
#
# ### Create spatiotemporal query using a STAC API as the backend
# This establishes the spatial and temporal extent used to search for Landsat satellite data.

# %%
# Load the data, mask it and generate composites.
# This is lazy-loaded, so no data is actually loaded yet.
ds, suninfo_by_day, meta = load_and_mask_data(
    config,
    geopolygon=geometry,
    include_nir=config.options.include_nir,
    debug=DEBUG,
    use_datacube=config.use_datacube,
)

ds
# Out:
# Loading with datacube
# Found 358 datasets
# <xarray.Dataset> Size: 866MB
# Dimensions:      (time: 192, y: 395, x: 408)
# Coordinates:
#   * time         (time) datetime64[us] 2kB 2019-01-09T02:41:24.241308 ... 202...
#   * y            (y) float64 3kB -7.506e+05 -7.507e+05 ... -7.624e+05 -7.625e+05
#   * x            (x) float64 3kB 5.818e+05 5.818e+05 ... 5.94e+05 5.94e+05
#     spatial_ref  int32 4B 32649
# Data variables:
#     green        (time, y, x) float32 124MB dask.array<chunksize=(1, 395, 408), meta=np.ndarray>
#     swir16       (time, y, x) float32 124MB dask.array<chunksize=(1, 395, 408), meta=np.ndarray>
#     qa_pixel     (time, y, x) float32 124MB dask.array<chunksize=(1, 395, 408), meta=np.ndarray>
#     nir08        (time, y, x) float32 124MB dask.array<chunksize=(1, 395, 408), meta=np.ndarray>
#     mndwi        (time, y, x) float32 124MB dask.array<chunksize=(1, 395, 408), meta=np.ndarray>
#     ndwi         (time, y, x) float32 124MB dask.array<chunksize=(1, 395, 408), meta=np.ndarray>
#     combined     (time, y, x) float32 124MB dask.array<chunksize=(1, 395, 408), meta=np.ndarray>
# Attributes:
#     crs:           EPSG:32649
#     grid_mapping:  spatial_ref

# %% [markdown]
# ## Tidal modelling

# %% [markdown]
# ### Interpolate tides into each satellite timestep
# For each satellite timestep, model tide heights into a low-resolution 5 x 5 km grid (matching resolution of the FES2014 tidal model), then reproject modelled tides into the spatial extent of our satellite image. Add  this new data as a new variable in our satellite dataset to allow each satellite pixel to be analysed and filtered/masked based on the tide height at the exact moment of satellite image acquisition.

# %%
filtered = filter_by_tides(
    ds,
    tide_data_location,
    config.options.tide_centre,
    config.options.tide_model,
    ensemble_model_list=config.options.ensemble_model_list,
    ensemble_model_rankings=config.options.ensemble_model_rankings,
)

print(
    f"Dropped {len(ds.time) - len(filtered.time)} out of {len(ds.time)} timesteps due to extreme tides"
)
# Out:
# Creating reduced resolution 5000 x 5000 metre tide modelling array
# Modelling tides with FES2022
# Returning low resolution tide array
# Dropped 79 out of 192 timesteps due to extreme tides

# %% [markdown]
# ## Generate yearly composites in memory
# Export tidally-masked MNDWI median composites for each year, and three-yearly composites used to gapfill poor data coverage areas.

# %%
# Optionally load the daily dataset into memory, either do this here or
# down below for the combined dataset. This takes more memory, but is
# faster. The below one results in a big, complex dask graph, but saves
# a fair bit of memory.
filtered = filtered.compute()
filtered
# Out:
# <xarray.Dataset> Size: 510MB
# Dimensions:      (time: 113, y: 395, x: 408)
# Coordinates:
#   * time         (time) datetime64[us] 904B 2019-02-10T02:41:18.128143 ... 20...
#   * y            (y) float64 3kB -7.506e+05 -7.507e+05 ... -7.624e+05 -7.625e+05
#   * x            (x) float64 3kB 5.818e+05 5.818e+05 ... 5.94e+05 5.94e+05
#     spatial_ref  int32 4B 32649
#     tide_model   <U7 28B 'FES2022'
# Data variables:
#     green        (time, y, x) float32 73MB nan nan nan nan ... nan nan nan nan
#     swir16       (time, y, x) float32 73MB nan nan nan nan ... nan nan nan nan
#     qa_pixel     (time, y, x) float32 73MB nan nan nan nan ... nan nan nan nan
#     nir08        (time, y, x) float32 73MB nan nan nan nan ... nan nan nan nan
#     mndwi        (time, y, x) float32 73MB nan nan nan nan ... nan nan nan nan
#     ndwi         (time, y, x) float32 73MB nan nan nan nan ... nan nan nan nan
#     combined     (time, y, x) float32 73MB nan nan nan nan ... nan nan nan nan
# Attributes:
#     crs:           EPSG:32649
#     grid_mapping:  spatial_ref

# %% [markdown]
# ## Specific masking
#
# First we do a per-pixel mask of the extreme tide pixels. This is done with data loaded into memory, to keep things efficient on memory and dask graphs.
#
# The graph below shows the percentage of data remaining each year after per-pixel masking.
#
# Second we do per-pixel hillshadow masking.
#
# ### Per-pixel tide masking

# %%
# Per-pixel tide masking
pixel_tide_masked = mask_pixels_by_tide(
    filtered,
    tide_data_location,
    config.options.tide_centre,
    config.options.tide_model,
    ensemble_model_list=config.options.ensemble_model_list,
    ensemble_model_rankings=config.options.ensemble_model_rankings,
)
# Out:
# Creating reduced resolution 5000 x 5000 metre tide modelling array
# Modelling tides with FES2022
# Returning low resolution tide array
# Creating reduced resolution 5000 x 5000 metre tide modelling array
# Modelling tides with FES2022
# Reprojecting tides into original resolution
# /home/jovyan/dev/coastlines/.venv/lib/python3.12/site-packages/rasterio/warp.py:385: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dest = _reproject(
# /home/jovyan/dev/coastlines/.venv/lib/python3.12/site-packages/rasterio/warp.py:385: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dest = _reproject(
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option DTYPE

# %%
# Plot the percentage of pixels remaining after high-res tide masking
filter_null_byyear = (
    filtered[config.options.water_index]
    .isnull()
    .groupby("time.year")
    .sum(dim=["time", "x", "y"])
)
masked_null_byyear = (
    pixel_tide_masked[config.options.water_index]
    .isnull()
    .groupby("time.year")
    .sum(dim=["time", "x", "y"])
)
diff = (filter_null_byyear / masked_null_byyear) * 100
diff.plot.line(x="year", ylim=[0, 110], figsize=(12, 4), yticks=range(0, 101, 20))

# %% [markdown]
# ### Per-pixel hillshade masking
#
# (Optional)

# %%
# Run a hillshade masking step. This is optional, but can help remove
# some noisy pixels from the analysis.

if config.options.mask_with_hillshade:
    try:
        pixel_tide_masked, hillshade = mask_pixels_by_hillshadow(
            pixel_tide_masked,
            suninfo_by_day,
            stac_catalog=config.options.hillshade_stac_catalog,
            stac_collection=config.options.hillshade_stac_collection,
            debug=True,
        )
    except CoastlinesException:
        print("No DEM available for this area. Skipping hillshade masking.")
# Out:
# 100%|██████████| 113/113 [00:00<00:00, 132.00it/s]

# %%
# In the below plot, anything that isn't a `0` has had some
# pixels masked out due to hillshade.
mean_hs = hillshade.mean(dim="time")
mean_hs.plot.imshow(size=10, vmin=0, vmax=1)

# %%
# Plot the percentage of pixels remaining after hillshade masking
shaded_null_byyear = (
    pixel_tide_masked[config.options.water_index]
    .isnull()
    .groupby("time.year")
    .sum(dim=["time", "x", "y"])
)
diff = (masked_null_byyear / shaded_null_byyear) * 100
diff.plot.line(x="year", ylim=[0, 110], figsize=(12, 4), yticks=range(0, 101, 20))

# %% [markdown]
# ## Create annual composites

# %%
# Create a yearly dataset, loaded into memory. This takes a long time!
combined_ds = generate_yearly_composites(
    pixel_tide_masked,
    config.options.start_year,
    config.options.end_year,
    water_index=config.options.water_index,
    include_nir=config.options.include_nir,
    debug=DEBUG,
)

# Load the combined dataset instead. Make sure you comment out the filtered
# load step. This will take longer, but use less memory.
combined_ds = combined_ds.compute()
combined_ds
# Out:
# Water index is combined
# <xarray.Dataset> Size: 36MB
# Dimensions:           (year: 4, y: 395, x: 408)
# Coordinates:
#   * year              (year) int64 32B 2020 2021 2022 2023
#   * y                 (y) float64 3kB -7.506e+05 -7.507e+05 ... -7.625e+05
#   * x                 (x) float64 3kB 5.818e+05 5.818e+05 ... 5.94e+05 5.94e+05
#     spatial_ref       int32 4B 32649
#     tide_model        <U7 28B 'FES2022'
# Data variables:
#     combined          (year, y, x) float32 3MB -0.5213 -0.5269 ... -0.484
#     count             (year, y, x) int64 5MB 13 13 13 13 13 13 ... 7 7 7 7 7 7
#     stdev             (year, y, x) float32 3MB 0.07386 0.06078 ... 0.05771
#     gapfill_combined  (year, y, x) float32 3MB -0.5213 -0.5269 ... -0.4855
#     gapfill_count     (year, y, x) int64 5MB 13 13 13 13 13 ... 22 22 22 22 22
#     gapfill_stdev     (year, y, x) float32 3MB 0.07386 0.06078 ... 0.07088
#     nir               (year, y, x) float32 3MB 0.3261 0.3312 ... 0.193 0.1981
#     gapfill_nir       (year, y, x) float32 3MB 0.3261 0.3312 ... 0.2242 0.213
#     green             (year, y, x) float32 3MB 0.1015 0.09725 ... 0.07932
#     swir              (year, y, x) float32 3MB 0.3278 0.3141 ... 0.2789 0.273
#     gapfill_green     (year, y, x) float32 3MB 0.1016 0.09752 ... 0.07908
#     gapfill_swir      (year, y, x) float32 3MB 0.3217 0.2878 ... 0.2797 0.2746

# %%
combined_ds[config.options.water_index].isel(year=-1).odc.explore(
    robust=True, cmap="RdBu", vmin=-0.2, vmax=1
)
# Out:
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option DTYPE
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c128ea2be8b126c724936910326e850d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c128ea2be8b126c724936910326e850d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c128ea2be8b126c724936910326e850d = L.map(
#                 &quot;map_c128ea2be8b126c724936910326e850d&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53ffc80b5269c01112a07e62f5d3e7c9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53ffc80b5269c01112a07e62f5d3e7c9.addTo(map_c128ea2be8b126c724936910326e850d);
#
#
#             var image_overlay_3b92b50cd4d2be7f40753eda49a94e20 = L.imageOverlay(
#                 &quot;...&quot;,
#                 [[-6.789876070506276, 111.73964773583022], [-6.897976065461147, 111.85121849411787]],
#                 {
# }
#             );
#
#
#             image_overlay_3b92b50cd4d2be7f40753eda49a94e20.addTo(map_c128ea2be8b126c724936910326e850d);
#
#
#             map_c128ea2be8b126c724936910326e850d.fitBounds(
#                 [[-6.790301989905985, 111.73989206010769], [-6.8973037733437845, 111.85084067416646]],
#                 {}
#             );
#
#
#             var layer_control_3d57232033fb21302d83d1d3be4752b0_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_53ffc80b5269c01112a07e62f5d3e7c9,
#                 },
#                 overlays :  {
#                     &quot;combined&quot; : image_overlay_3b92b50cd4d2be7f40753eda49a94e20,
#                 },
#             };
#             let layer_control_3d57232033fb21302d83d1d3be4752b0 = L.control.layers(
#                 layer_control_3d57232033fb21302d83d1d3be4752b0_layers.base_layers,
#                 layer_control_3d57232033fb21302d83d1d3be4752b0_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_c128ea2be8b126c724936910326e850d);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
_ = combined_ds[config.options.water_index].isel(year=-1).plot.hist(bins=100)

# %%
# # Uncomment the below to save data

# if output_cache_zarr.exists():
#     import shutil

#     print(f"Folder {output_cache_zarr} already exists. Deleting...")
#     shutil.rmtree(output_cache_zarr)

# combined_ds.to_zarr(output_cache_zarr)

# %%
# # Uncomment the below to load data
# import xarray as xr

# combined_ds = xr.open_zarr(output_cache_zarr).load()
# combined_ds

# %% [markdown]
# ## Load vector data and pre-process raster data

# %%
# Coastal mask modifications with "add" and "remove" areas
modifications_gdf = gpd.read_file(
    config.input.modifications_path, mask=geometry
).to_crs(str(combined_ds.odc.crs))

# Mask dataset to focus on coastal zone only
(
    masked_ds,
    certainty_masks,
    all_time_20,
    all_time_80,
    river_mask,
    ocean_da,
    thresholded_ds,
    temporal_mask,
    annual_mask,
    coastal_mask,
    ocean_mask,
) = contours_preprocess(
    combined_ds=combined_ds,
    water_index=config.options.water_index,
    index_threshold=config.options.index_threshold,
    buffer_pixels=33,
    modifications_gdf=modifications_gdf,
    include_nir=True,
    debug=True,
)

masked_ds.isel(year=0).odc.explore(cmap="RdBu", tiles=basemaps.Esri.WorldImagery)
# Out:
# WARNING:rasterio._env:CPLE_AppDefined in DeprecationWarning: 'Memory' driver is deprecated since GDAL 3.11. Use 'MEM' onwards. Further messages of this type will be suppressed.
# WARNING:rasterio._env:CPLE_AppDefined in DeprecationWarning: 'Memory' driver is deprecated since GDAL 3.11. Use 'MEM' onwards. Further messages of this type will be suppressed.
# WARNING:rasterio._env:CPLE_AppDefined in DeprecationWarning: 'Memory' driver is deprecated since GDAL 3.11. Use 'MEM' onwards. Further messages of this type will be suppressed.
# WARNING:rasterio._env:CPLE_AppDefined in DeprecationWarning: 'Memory' driver is deprecated since GDAL 3.11. Use 'MEM' onwards. Further messages of this type will be suppressed.
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option DTYPE
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_133cd7fa936f367e4110eea732dfe45f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_133cd7fa936f367e4110eea732dfe45f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_133cd7fa936f367e4110eea732dfe45f = L.map(
#                 &quot;map_133cd7fa936f367e4110eea732dfe45f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebf928ddf08e4b6bcc0e5bb9edd03c27 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ebf928ddf08e4b6bcc0e5bb9edd03c27.addTo(map_133cd7fa936f367e4110eea732dfe45f);
#
#
#             var image_overlay_f1c4c7550a43c09ed289b9eaeed2d8c1 = L.imageOverlay(
#                 &quot;...&quot;,
#                 [[-6.789876070506276, 111.73964773583022], [-6.897976065461147, 111.85121849411787]],
#                 {
# }
#             );
#
#
#             image_overlay_f1c4c7550a43c09ed289b9eaeed2d8c1.addTo(map_133cd7fa936f367e4110eea732dfe45f);
#
#
#             map_133cd7fa936f367e4110eea732dfe45f.fitBounds(
#                 [[-6.790301989905985, 111.73989206010769], [-6.8973037733437845, 111.85084067416646]],
#                 {}
#             );
#
#
#             var layer_control_4749ce6c354779177816249b7eb5aca7_layers = {
#                 base_layers : {
#                     &quot;esriworldimagery&quot; : tile_layer_ebf928ddf08e4b6bcc0e5bb9edd03c27,
#                 },
#                 overlays :  {
#                     &quot;combined&quot; : image_overlay_f1c4c7550a43c09ed289b9eaeed2d8c1,
#                 },
#             };
#             let layer_control_4749ce6c354779177816249b7eb5aca7 = L.control.layers(
#                 layer_control_4749ce6c354779177816249b7eb5aca7_layers.base_layers,
#                 layer_control_4749ce6c354779177816249b7eb5aca7_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_133cd7fa936f367e4110eea732dfe45f);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Extract shorelines
contours = subpixel_contours(
    da=masked_ds,
    z_values=config.options.index_threshold,
    min_vertices=10,
    dim="year",
).set_index("year")

# Add quality measures
contours_with_certainty = contour_certainty(contours, certainty_masks)

# Plot shorelines
contours_with_certainty.reset_index().explore(
    column="year", cmap="magma", tiles=basemaps.Esri.WorldImagery
)
# Out:
# Operating in single z-value, multiple arrays mode
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_254626b971de4f56d2d03fc08df48a32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_254626b971de4f56d2d03fc08df48a32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_254626b971de4f56d2d03fc08df48a32 = L.map(
#                 &quot;map_254626b971de4f56d2d03fc08df48a32&quot;,
#                 {
#                     center: [-6.795626457103342, 111.82612473068102],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_254626b971de4f56d2d03fc08df48a32);
#
#
#
#
#
#             var tile_layer_e4d27399d47589afb4477528a2eeb301 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e4d27399d47589afb4477528a2eeb301.addTo(map_254626b971de4f56d2d03fc08df48a32);
#
#
#             map_254626b971de4f56d2d03fc08df48a32.fitBounds(
#                 [[-6.800913956195344, 111.80171633115677], [-6.790338958011341, 111.85053313020525]],
#                 {}
#             );
#
#
#         function geo_json_c21ab30b28895892de6569cd0fbb7432_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#000004&quot;, &quot;fillColor&quot;: &quot;#000004&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#721f81&quot;, &quot;fillColor&quot;: &quot;#721f81&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#f1605d&quot;, &quot;fillColor&quot;: &quot;#f1605d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#fcfdbf&quot;, &quot;fillColor&quot;: &quot;#fcfdbf&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_c21ab30b28895892de6569cd0fbb7432_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_c21ab30b28895892de6569cd0fbb7432_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_c21ab30b28895892de6569cd0fbb7432_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_c21ab30b28895892de6569cd0fbb7432_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_c21ab30b28895892de6569cd0fbb7432.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c21ab30b28895892de6569cd0fbb7432_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c21ab30b28895892de6569cd0fbb7432 = L.geoJson(null, {
#                 onEachFeature: geo_json_c21ab30b28895892de6569cd0fbb7432_onEach

# %% [markdown]
# ## Compute statistics
#
# ### Measure annual coastline movements

# %%
from coastlines.combined import extract_points_with_movements

points = extract_points_with_movements(
    combined_ds,
    contours_with_certainty,
    config.options.baseline_year,
    config.options.start_year,
    config.options.end_year,
    water_index=config.options.water_index,
)

# %%
geomorphology_url = config.input.geomorphology_path
geomorphology_gdf = gpd.read_file(
    geomorphology_url,
    mask=geometry,
)

# And add certainty
points_with_certainty = points_certainty(
    points,
    geomorphology_gdf=geomorphology_gdf,
    baseline_year=config.options.baseline_year,
    rocky_query="(Preds == 'Bedrock') and (Probs > 0.75)",
)

# %%
# Generate hotspots
hotspots = generate_hotspots(
    contours_with_certainty,
    points_with_certainty,
    [10000, 5000, 1000],
    config.options.baseline_year,
)

# Visualise the 10_000 m hotspots
hotspots[0].explore(
    column="rate_time",
    cmap="RdYlGn",
    marker_kwds={
        "radius": 10,
        "fill_opacity": 0.8,
    },
    tiles=basemaps.Esri.WorldImagery,
)

# %% [markdown]
# ## Export files

# %%
clipped_points_gdf = points_with_certainty.clip(
    geometry.to_crs(points_with_certainty.crs).geom
)
clipped_contours_gdf = contours_with_certainty.clip(
    geometry.to_crs(contours_with_certainty.crs).geom
)

out_files = export_results(
    clipped_points_gdf, clipped_contours_gdf, version, str(output_dir), study_area
)

for out_file in out_files:
    print(f"Exported {out_file}")
# Out:
# Exported data/processed/testing/1869_049_testing/testing/points_1869_049.parquet
# Exported data/processed/testing/1869_049_testing/testing/contours_1869_049.parquet

# %% [markdown]
# ### Close Dask client

# %%
dask_client.close()

# %% [markdown]
# ***
#
# ## Additional information

# %% [markdown]
# **License:** The code in this notebook is licensed under the [Apache License, Version 2.0](https://www.apache.org/licenses/LICENSE-2.0).
# Digital Earth Australia data is licensed under the [Creative Commons by Attribution 4.0](https://creativecommons.org/licenses/by/4.0/) license.
#
# **Contact:** For assistance with any of the Python code or Jupyter Notebooks in this repository, please post a [Github issue](https://github.com/GeoscienceAustralia/dea-coastlines/issues/new).
#
# **Last modified:** November 2022
#
# **To cite:**
#
# > Bishop-Taylor, R., Nanson, R., Sagar, S., Lymburner, L. (2021). Mapping Australia's dynamic coastline at mean sea level using three decades of Landsat imagery. Remote Sensing of Environment, 267, 112734. Available: https://doi.org/10.1016/j.rse.2021.112734
# >
# > Nanson, R., Bishop-Taylor, R., Sagar, S., Lymburner, L., (2022). Geomorphic insights into Australia's coastal change using a national dataset derived from the multi-decadal Landsat archive. Estuarine, Coastal and Shelf Science, 265, p.107712. Available: https://doi.org/10.1016/j.ecss.2021.107712
# >
# > Bishop-Taylor, R., Sagar, S., Lymburner, L., Alam, I., Sixsmith, J. (2019). Sub-pixel waterline extraction: characterising accuracy and sensitivity to indices and spectra. Remote Sensing, 11 (24):2984. Available: https://doi.org/10.3390/rs11242984
